# %%
import pandas as pd

# %%
accidents = pd.read_csv('../data/vehicles2004.csv')

# %%
accidents.head()
# Out:
#    Unnamed: 0   �..Acc_Index  Vehicle_Reference  Vehicle_Type  \
# 0           1  200401BS00001                  1             3
# 1           2  200401BS00001                  2           109
# 2           3  200401BS00002                  1           109
# 3           4  200401BS00003                  1           109
# 4           5  200401BS00003                  2           109
#
#    Towing_and_Articulation  Vehicle_Manoeuvre  \
# 0                        0                 18
# 1                        0                 18
# 2                        0                 18
# 3                        0                  9
# 4                        0                 18
#
#    Vehicle_Location.Restricted_Lane  Junction_Location  \
# 0                                 0                 -1
# 1                                 0                 -1
# 2                                 0                 -1
# 3                                 0                 -1
# ...
